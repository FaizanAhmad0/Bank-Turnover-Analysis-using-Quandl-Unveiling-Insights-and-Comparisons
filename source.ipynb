# %%
import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
quandl.ApiConfig.api_key = 'k5hpQXTQmkr3f2cBYTDb'
names_of_company = ['HBL']
n2=['ABL']
n3=['UBL']
n4=['BOP']
#names_of_company = ['HBL','ABL','UBL','BOP']
results = pd.DataFrame()
r2 = pd.DataFrame()
r3 = pd.DataFrame()
r4 = pd.DataFrame()
for names in names_of_company:
    x = quandl.get('PSX/%s' %names, start_date='2011-1-1',
    end_date='2022-5-1')
    x['company'] = names
    results = results.append(x)
    
for names in n2:
    x = quandl.get('PSX/%s' %names, start_date='2011-1-1',
    end_date='2022-5-1')
    x['company'] = names
    r2 = r2.append(x)
    
for names in n3:
    x = quandl.get('PSX/%s' %names, start_date='2011-1-1',
    end_date='2022-5-1')
    x['company'] = names
    r3 = r3.append(x)
    
for names in n4:
    x = quandl.get('PSX/%s' %names, start_date='2011-1-1',
    end_date='2022-5-1')
    x['company'] = names
    r4 = r4.append(x)
# Out:
# C:\Users\Faizan\AppData\Local\Temp\ipykernel_19384\4161916372.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(x)
# C:\Users\Faizan\AppData\Local\Temp\ipykernel_19384\4161916372.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   r2 = r2.append(x)
# C:\Users\Faizan\AppData\Local\Temp\ipykernel_19384\4161916372.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   r3 = r3.append(x)
# C:\Users\Faizan\AppData\Local\Temp\ipykernel_19384\4161916372.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   r4 = r4.append(x)

# %%
results
# Out:
#               Open    High     Low   Turnover   Close company
# Date
# 2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL
# 2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL
# 2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL
# 2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL
# 2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL
# ...            ...     ...     ...        ...     ...     ...
# 2021-07-26  129.98  130.45  128.10   607740.0  128.76     HBL
# 2021-07-27  127.80  131.95  127.80  2267549.0  131.31     HBL
# 2021-07-28  131.90  131.90  129.55   802489.0  130.80     HBL
# 2021-07-29  131.00  131.00  128.50   531104.0  128.93     HBL
# 2021-07-30  129.00  129.47  126.00  2104560.0  126.67     HBL
#
# [2594 rows x 6 columns]

# %%
r2
# Out:
#              Open   High    Low   Turnover  Close company
# Date
# 2011-01-03  70.15  70.00  67.40   127600.0  70.15     ABL
# 2011-01-04  67.83  71.22  68.45   585236.0  67.83     ABL
# 2011-01-05  70.77  72.99  70.01  1200042.0  70.77     ABL
# 2011-01-06  71.82  72.80  71.50   708497.0  71.82     ABL
# 2011-01-07  71.75  72.06  71.35   168166.0  71.75     ABL
# ...           ...    ...    ...        ...    ...     ...
# 2021-07-26  71.99  72.00  71.85   233000.0  71.85     ABL
# 2021-07-27  71.99  73.10  71.75    86500.0  73.00     ABL
# 2021-07-28  73.01  73.73  72.50    99000.0  73.01     ABL
# 2021-07-29  72.99  73.00  72.50    11500.0  72.75     ABL
# 2021-07-30  72.51  72.51  72.05    83000.0  72.05     ABL
#
# [2572 rows x 6 columns]

# %%
r3
# Out:
#               Open    High     Low   Turnover   Close company
# Date
# 2011-01-03   68.23   67.94   65.10  2378598.0   68.23     UBL
# 2011-01-04   65.59   67.10   65.55  3237772.0   65.59     UBL
# 2011-01-05   66.61   67.70   65.75  2947076.0   66.61     UBL
# 2011-01-06   65.99   66.80   66.15  1205505.0   65.99     UBL
# 2011-01-07   66.53   67.60   66.20  1651016.0   66.53     UBL
# ...            ...     ...     ...        ...     ...     ...
# 2021-07-26  127.88  127.88  124.50   805954.0  125.18     UBL
# 2021-07-27  125.00  128.00  124.16   912859.0  127.49     UBL
# 2021-07-28  127.50  127.79  126.53   542118.0  127.01     UBL
# 2021-07-29  127.48  127.48  125.45   360901.0  126.19     UBL
# 2021-07-30  126.95  126.95  124.50  1071862.0  124.99     UBL
#
# [2594 rows x 6 columns]

# %%
r4
# Out:
#              Open   High   Low    Turnover  Close company
# Date
# 2011-01-03   9.81   9.70  9.40   1365630.0   9.81     BOP
# 2011-01-04   9.42   9.69  9.35    826201.0   9.42     BOP
# 2011-01-05   9.65  10.06  9.61   2712097.0   9.65     BOP
# 2011-01-06   9.84  10.21  9.91   3331121.0   9.84     BOP
# 2011-01-07  10.03  10.15  9.85    954110.0  10.03     BOP
# ...           ...    ...   ...         ...    ...     ...
# 2021-07-26   8.26   8.35  8.17   1538000.0   8.21     BOP
# 2021-07-27   8.25   8.60  8.20  10885500.0   8.41     BOP
# 2021-07-28   8.48   8.48  8.25   2241000.0   8.28     BOP
# 2021-07-29   8.30   8.30  8.20   1400000.0   8.22     BOP
# 2021-07-30   8.21   8.35  8.17   3124000.0   8.20     BOP
#
# [2594 rows x 6 columns]

# %%
results.to_csv("banks_HBL.csv")
r2.to_csv("banks_ABL.csv")
r3.to_csv("banks_UBL.csv")
r4.to_csv("banks_BOP.csv")

# %%
df=pd.read_csv("banks_HBL.csv")
df2=pd.read_csv("banks_ABL.csv")
df3=pd.read_csv("banks_UBL.csv")
df4=pd.read_csv("banks_BOP.csv")
df
# Out:
#             Date    Open    High     Low   Turnover   Close company
# 0     2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL
# 1     2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL
# 2     2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL
# 3     2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL
# 4     2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL
# ...          ...     ...     ...     ...        ...     ...     ...
# 2589  2021-07-26  129.98  130.45  128.10   607740.0  128.76     HBL
# 2590  2021-07-27  127.80  131.95  127.80  2267549.0  131.31     HBL
# 2591  2021-07-28  131.90  131.90  129.55   802489.0  130.80     HBL
# 2592  2021-07-29  131.00  131.00  128.50   531104.0  128.93     HBL
# 2593  2021-07-30  129.00  129.47  126.00  2104560.0  126.67     HBL
#
# [2594 rows x 7 columns]

# %%
df2
# Out:
#             Date   Open   High    Low   Turnover  Close company
# 0     2011-01-03  70.15  70.00  67.40   127600.0  70.15     ABL
# 1     2011-01-04  67.83  71.22  68.45   585236.0  67.83     ABL
# 2     2011-01-05  70.77  72.99  70.01  1200042.0  70.77     ABL
# 3     2011-01-06  71.82  72.80  71.50   708497.0  71.82     ABL
# 4     2011-01-07  71.75  72.06  71.35   168166.0  71.75     ABL
# ...          ...    ...    ...    ...        ...    ...     ...
# 2567  2021-07-26  71.99  72.00  71.85   233000.0  71.85     ABL
# 2568  2021-07-27  71.99  73.10  71.75    86500.0  73.00     ABL
# 2569  2021-07-28  73.01  73.73  72.50    99000.0  73.01     ABL
# 2570  2021-07-29  72.99  73.00  72.50    11500.0  72.75     ABL
# 2571  2021-07-30  72.51  72.51  72.05    83000.0  72.05     ABL
#
# [2572 rows x 7 columns]

# %% [markdown]
# # Q1

# %%
#plot date and turn over of HBL and skip 100 ticks
#set fig size
plt.figure(figsize=(25,25))
plt.subplot(2,2,1)
#plot date and turn over of HBL
plt.plot(df['Date'],df['Turnover'], color ='g', label = ["HBL Turnover"])
plt.title("Daily Turnover for HBL")
plt.xlabel("Date")
plt.ylabel("Turnover")
plt.legend()
plt.xticks(df['Date'][::100])
plt.xticks(rotation=90)


plt.subplot(2,2,2)
#plot date and turn over of ABL
plt.plot(df2['Date'],df2['Turnover'], label = ["ABL Turnover"])
plt.title("Daily Turnover for ABL")
plt.xlabel("Date")
plt.ylabel("Turnover")
plt.legend()
plt.xticks(df2['Date'][::100])
plt.xticks(rotation=90)


plt.subplot(2,2,3)
#plot date and turn over of UBL
plt.plot(df3['Date'],df3['Turnover'],color ='m', label = ["UBL Turnover"])
plt.title("Daily Turnover for UBL")
plt.xlabel("Date")
plt.ylabel("Turnover")
plt.legend()
plt.xticks(df3['Date'][::100])
plt.xticks(rotation=90)

plt.subplot(2,2,4)
#plot date and turn over of BOP
plt.plot(df4['Date'],df4['Turnover'],color ='b', label = ["BOP Turnover"])
plt.title("Daily Turnover for BOP")
plt.xlabel("Date")
plt.ylabel("Turnover")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)
#show plot
plt.show()

# %%
df['Date']=pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Year']=pd.DatetimeIndex(df['Date']).year
df['Month']=pd.DatetimeIndex(df['Date']).month

# %% [markdown]
# # Q_2

# %%
#(open price – previous close price)
df['Price Change']=df['Open']-df['Close'].shift(1)
df2['Price Change']=df2['Open']-df2['Close'].shift(1)
df3['Price Change']=df3['Open']-df3['Close'].shift(1)
df4['Price Change']=df4['Open']-df4['Close'].shift(1)

# %%
plt.figure(figsize=(25,25))
plt.subplot(2,2,1)
plt.plot(df['Date'], df['Price Change'],color ='m', label = ["HBL Price Change"])
plt.title("Daily Price Change for HBL")
plt.xlabel("Date")
plt.ylabel("Price Change")
plt.legend()

plt.subplot(2,2,2)
plt.plot(df2['Date'], df2['Price Change'],color ='g', label = ["ABL Price Change"])
plt.title("Daily Price Change for ABL")
plt.xlabel("Date")
plt.ylabel("Price Change")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)

plt.subplot(2,2,3)
plt.plot(df3['Date'], df3['Price Change'],color ='y', label = ["UBL Price Change"])
plt.title("Daily Price Change for ABL")
plt.xlabel("Date")
plt.ylabel("Price Change")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)

plt.subplot(2,2,4)
plt.plot(df4['Date'], df4['Price Change'],color ='red', label = ["BOP Price Change"])
plt.title("Daily Price Change for BOP")
plt.xlabel("Date")
plt.ylabel("Price Change")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q_3

# %%
df['Date']=pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Year']=pd.DatetimeIndex(df['Date']).year
df['Month']=pd.DatetimeIndex(df['Date']).month
#ABL
df2['Date']=pd.to_datetime(df2['Date'], format='%Y-%m-%d')
df2['Year']=pd.DatetimeIndex(df2['Date']).year
df2['Month']=pd.DatetimeIndex(df2['Date']).month
#UBL
df3['Date']=pd.to_datetime(df3['Date'], format='%Y-%m-%d')
df3['Year']=pd.DatetimeIndex(df3['Date']).year
df3['Month']=pd.DatetimeIndex(df3['Date']).month
#BOP
df4['Date']=pd.to_datetime(df4['Date'], format='%Y-%m-%d')
df4['Year']=pd.DatetimeIndex(df4['Date']).year
df4['Month']=pd.DatetimeIndex(df4['Date']).month

# %%
plt.figure(figsize=(25,25))
plt.subplot(2,2,1)
a1=pd.DataFrame()
a1=df.groupby(pd.PeriodIndex(df['Date'], freq="M"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='g', label = ["HBL Monthly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Monthly Mean")
plt.legend()

plt.subplot(2,2,2)
a1=pd.DataFrame()
a1=df2.groupby(pd.PeriodIndex(df2['Date'], freq="M"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='m', label = ["ABL Monthly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Monthly Mean")
plt.legend()

plt.subplot(2,2,3)
a1=pd.DataFrame()
a1=df3.groupby(pd.PeriodIndex(df3['Date'], freq="M"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='b', label = ["UBL Monthly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Monthly Mean")
plt.legend()

plt.subplot(2,2,4)
a1=pd.DataFrame()
a1=df4.groupby(pd.PeriodIndex(df4['Date'], freq="M"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='red', label = ["BOP Monthly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Monthly Mean")
plt.legend()
plt.title("Monthly Mean of all companies")
plt.show()

# %%
plt.figure(figsize=(25,25))
plt.subplot(2,2,1)
a1=pd.DataFrame()
a1=df.groupby(pd.PeriodIndex(df['Date'], freq="Y"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='m', label = ["HBL Yearly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Yearly Mean")
plt.legend()

plt.subplot(2,2,2)
a1=pd.DataFrame()
a1=df2.groupby(pd.PeriodIndex(df2['Date'], freq="Y"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='red', label = ["ABL Yearly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Yearly Mean")
plt.legend()

plt.subplot(2,2,3)
a1=pd.DataFrame()
a1=df3.groupby(pd.PeriodIndex(df3['Date'], freq="Y"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='b', label = ["UBL Yearly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Yearly Mean")
plt.legend()

plt.subplot(2,2,4)
a1=pd.DataFrame()
a1=df4.groupby(pd.PeriodIndex(df4['Date'], freq="Y"))['Close'].mean()
a1=a1.to_frame()
a1.index = a1.index.to_timestamp()
plt.plot(a1.index,a1.Close,color ='gray', label = ["BOP Yearly Close Mean"])
plt.xlabel("Date")
plt.ylabel("Yearly Mean")
plt.legend()
plt.title("Yearly Mean of all companies")
plt.show()

# %% [markdown]
# # Q4

# %%
df['Daily Returns']=(df['Close'].shift(1)/df['Close'])-1
df2['Daily Returns']=(df2['Close'].shift(1)/df2['Close'])-1
df3['Daily Returns']=(df3['Close'].shift(1)/df3['Close'])-1
df4['Daily Returns']=(df4['Close'].shift(1)/df4['Close'])-1

# %%
plt.figure(figsize=(25,25))
plt.subplot(2,2,1)
plt.plot(df['Date'],df['Daily Returns'],color='red', label = ["HBL Daily Returns"])
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.legend()
plt.subplot(2,2,2)
plt.plot(df2['Date'],df2['Daily Returns'],color='m', label = ["ABL Daily Returns"])
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)
plt.subplot(2,2,3)
plt.plot(df3['Date'],df3['Daily Returns'],color='g', label = ["UBL Daily Returns"])
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)
plt.subplot(2,2,4)
plt.plot(df4['Date'],df4['Daily Returns'],color='gray', label = ["BOP Daily Returns"])
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.legend()
plt.xticks(df4['Date'][::100])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Q_5

# %%
hbl=df.sort_values(['Daily Returns','Date'],ascending=[True,True])
hbl=hbl.dropna()

abl=df2.sort_values(['Daily Returns','Date'],ascending=[True,True])
abl=abl.dropna()

ubl=df3.sort_values(['Daily Returns','Date'],ascending=[True,True])
ubl=ubl.dropna()

bop=df4.sort_values(['Daily Returns','Date'],ascending=[True,True])
bop=bop.dropna()

# %%
print("Worst Single Day Return HBL")

print(hbl['Date'].iloc[0],'  Daily Returns : ',hbl['Daily Returns'].iloc[0])

print("Best Single Day Return HBL")

print(hbl['Date'].iloc[-1],'  Daily Returns : ',hbl['Daily Returns'].iloc[-1])
# Out:
# Worst Single Day Return HBL
# 2018-01-19 00:00:00   Daily Returns :  -0.1171441206820304
# Best Single Day Return HBL
# 2011-03-15 00:00:00   Daily Returns :  0.1574468085106382

# %%
print("Worst Single Day Return ABL")

print(abl['Date'].iloc[0],'  Daily Returns : ',abl['Daily Returns'].iloc[0])

print("Best Single Day Return ABL")

print(abl['Date'].iloc[-1],'  Daily Returns : ',abl['Daily Returns'].iloc[-1])
# Out:
# Worst Single Day Return ABL
# 2020-04-03 00:00:00   Daily Returns :  -0.06972499391579468
# Best Single Day Return ABL
# 2012-03-20 00:00:00   Daily Returns :  0.16263033972418417

# %%
print("Worst Single Day Return UBL")

print(ubl['Date'].iloc[0],'  Daily Returns : ',ubl['Daily Returns'].iloc[0])

print("Best Single Day Return UBL")

print(ubl['Date'].iloc[-1],'  Daily Returns : ',ubl['Daily Returns'].iloc[-1])
# Out:
# Worst Single Day Return UBL
# 2020-06-03 00:00:00   Daily Returns :  -0.06969130028063608
# Best Single Day Return UBL
# 2013-03-19 00:00:00   Daily Returns :  0.09726481049920266

# %%
print("Worst Single Day Return BOP")

print(bop['Date'].iloc[0],'  Daily Returns : ',bop['Daily Returns'].iloc[0])

print("Best Single Day Return BOP")

print(bop['Date'].iloc[-1],'  Daily Returns : ',bop['Daily Returns'].iloc[-1])
# Out:
# Worst Single Day Return BOP
# 2011-05-26 00:00:00   Daily Returns :  -0.16260162601626016
# Best Single Day Return BOP
# 2020-03-19 00:00:00   Daily Returns :  0.16598079561042534

# %% [markdown]
# # Q_6

# %%
banks=['HBL','ABL','UBL','BOP']
s1=st.stdev(df['Turnover'])
s2=st.stdev(df2['Turnover'])
s3=st.stdev(df3['Turnover'])
s4=st.stdev(df4['Turnover'])

# %%
plt.bar(banks,[s1,s2,s3,s4],color ='m', label = ["Standard Deviation of Stocks in all Banks"])
plt.xlabel("Banks")
plt.ylabel("Turnover")
plt.legend()

# %% [markdown]
# # Q_7

# %%
plt.plot(df['Close'],label = ["HBL Close Rate"])


plt.plot(df2['Close'], label = ["ABL Close Rate"])
plt.plot(df3['Close'], label = ["UBL Close Rate"])
plt.plot(df4['Close'], label = ["BOP Close Rate"])
plt.title("Daily Close Rate for All Banks")
plt.legend()
#plt.show()

# %% [markdown]
# # Q_8

# %%
fig=plt.figure(figsize=(25,25))
ax = fig.add_axes([0,0,1,1])
width=0.8
plt.subplot(2,2,1)

plt.bar(df['Year'], df['Turnover'], color = "m",
        label =" Yearly Turnover of HBL") #visible=False

plt.bar(df2['Year'], df2['Turnover'], color = "g",
        label ="Yearly Turnover of ABL") 
#plt.yticks(df['Date'], df['Close'], rotation = 20)
plt.title("Yearly Turnover for HBL and ABL", fontsize = 18)
plt.ylabel("Turnover",fontsize = 15)
plt.xlabel("Year", fontsize = 15)
plt.legend()
plt.show()

# %%
plt.plot(df2['Open'], label = ["ABL Opening Price"])
plt.plot(df3['Open'], label = ["UBL Opening Price"])
plt.title("Opening price of UBL and ABL")
plt.xlabel("Turnover",fontsize = 15)
plt.legend()
plt.show()

# %%
plt.plot(df2['Year'], df2['Open'],color ='g', linewidth = 3,markersize = 10, label = ["ABL Yearly Open Price"])
plt.title("Yearly Opening Price of ABL Bank")
plt.xlabel("Year")
plt.ylabel("Opening Price")
plt.legend()

plt.show()
